# %% [markdown]
# # 04 — Recourse Dataset + Level 1: Prediction Fairness
#
# **Author:** Matteo
#
# Integrates with the team's pipeline:
#   - Reads `.npy` splits from `data/processed/` (output of 1_Preprocessing.ipynb)
#   - Reads model artifacts from `data/models/RF/` and `data/models/XGBoost/`
#     (output of 2_Random_Forest.ipynb and 2_XGboost.ipynb)
#   - Reads counterfactual setup from utils.py (reuses Kamila's DiCE functions)
#   - Saves results to `data/fairness/`

# %% [markdown]
# ## 0. Setup — install dependencies and load utils

# %%
import os
import subprocess, sys

# Install missing packages if needed (works both locally and on Colab)
subprocess.run([sys.executable, "-m", "pip", "install", "dice-ml", "xgboost", "-q"])
# Out:
# CompletedProcess(args=['/opt/miniconda3/bin/python', '-m', 'pip', 'install', 'dice-ml', 'xgboost', '-q'], returncode=0)

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import dice_ml

import utils
from utils import (
    ScaledModelWrapper, load_artifacts, load_raw_with_split,
    build_recourse_dataset, get_project_paths,
    PROTECTED_ATTRIBUTES, SEED_DICE,
)

# Auto-detects Colab vs local VSCode and returns the correct paths
PATHS = get_project_paths()

print("Project paths:")
for k, v in PATHS.items():
    print(f"  {k}: {v}")

THRESHOLD = 0.20
N_CF      = 3
# Out:
# Project paths:
#   BASE: /Users/matteopaolini/Library/Mobile Documents/com~apple~CloudDocs/erasmus/Secondo semestre/INFO-H512/project/infoh512-project-1
#   DATA: /Users/matteopaolini/Library/Mobile Documents/com~apple~CloudDocs/erasmus/Secondo semestre/INFO-H512/project/infoh512-project-1/data/processed
#   RF: /Users/matteopaolini/Library/Mobile Documents/com~apple~CloudDocs/erasmus/Secondo semestre/INFO-H512/project/infoh512-project-1/data/models/RF
#   XGBoost: /Users/matteopaolini/Library/Mobile Documents/com~apple~CloudDocs/erasmus/Secondo semestre/INFO-H512/project/infoh512-project-1/data/models/XGBoost
#   FAIRNESS: /Users/matteopaolini/Library/Mobile Documents/com~apple~CloudDocs/erasmus/Secondo semestre/INFO-H512/project/infoh512-project-1/data/fairness

# %% [markdown]
# ## 1. Load data (readable demographics) and model artifacts

# %%
df_raw, df_encoded, feature_cols = load_raw_with_split()
print(f"Dataset: {df_raw.shape[0]} employees, {len(feature_cols)} features")
print(f"True attrition rate: {df_raw['Attrition'].mean():.1%}")
# Out:
# Dataset: 1470 employees, 30 features
# True attrition rate: 16.1%

# %%
rf  = load_artifacts(PATHS["RF"])
xgb = load_artifacts(PATHS["XGBoost"])
feature_names = rf["feature_names"]

rf_wrapper  = ScaledModelWrapper(rf["model"],  rf["scaler"],  feature_names)
xgb_wrapper = ScaledModelWrapper(xgb["model"], xgb["scaler"], feature_names)
print("Models loaded successfully.")
# Out:
# Models loaded successfully.

# %% [markdown]
# ## 2. Build DiCE explainers (reusing the team's exact configuration)

# %%
dice_df = df_encoded[feature_names].astype("float64").copy()
dice_df["Attrition"] = df_encoded["Attrition"].values

dice_data = dice_ml.Data(
    dataframe=dice_df,
    continuous_features=list(feature_names),
    outcome_name="Attrition",
)
dice_rf  = dice_ml.Model(model=rf_wrapper,  backend="sklearn", model_type="classifier")
dice_xgb = dice_ml.Model(model=xgb_wrapper, backend="sklearn", model_type="classifier")
exp_rf  = dice_ml.Dice(dice_data, dice_rf,  method="random")
exp_xgb = dice_ml.Dice(dice_data, dice_xgb, method="random")
print("DiCE explainers ready.")
# Out:
# DiCE explainers ready.

# %% [markdown]
# ## 3. Generate recourse dataset on ALL at-risk employees
#
# ⚠️ This is the slow step (~5-10 min). Results are checkpointed every 25
# employees so a crash never loses all progress.

# %%
recourse_rf = build_recourse_dataset(
    exp_rf, rf_wrapper, df_encoded, df_raw, feature_names,
    le_dict=rf["label_encoders"], n_cf=N_CF, seed=SEED_DICE,
    threshold=THRESHOLD,
    checkpoint_path=os.path.join(PATHS["FAIRNESS"], "recourse_RF.csv"),
)
# Out:
# Employees flagged at-risk (proba >= 0.2): 281
# 100%|██████████| 1/1 [00:00<00:00,  4.56it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.41it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.10it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.27it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.36it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.50it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.60it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.50it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.49it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.43it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.67it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.45it/s]
# 100%|██████████| 1/1 [00:02<00:00,  2.75s/it]
# 100%|██████████| 1/1 [00:00<00:00,  5.42it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.51it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.32it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.84it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.69it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.12it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.43it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.34it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.57it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.49it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.82it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.76it/s]
#   processed 25 / 281
# 100%|██████████| 1/1 [00:00<00:00,  5.20it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.29it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.58it/s]
# 100%|██████████| 1/1 [00:00<00:00,  2.53it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.49it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.32it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.29it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.26it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.40it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.04it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.45it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.62it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.93it/s]
# 100%|██████████| 1/1 [00:00<00:00,  2.50it/s]
# 100%|██████████| 1/1 [00:00<00:00,  2.86it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.86it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.05it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.52it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.46it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.50it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.54it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.84it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.45it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.37it/s]
# 100%|██████████| 1/1 [00:22<00:00, 22.58s/it]
#   processed 50 / 281
# 100%|██████████| 1/1 [00:00<00:00,  3.40it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.45it/s]
# 100%|██████████| 1/1 [00:00<00:00,  2.55it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.78it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.34it/s]
# 100%|██████████| 1/1 [00:21<00:00, 21.40s/it]
# 100%|██████████| 1/1 [00:00<00:00,  4.17it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.17it/s]
# 100%|██████████| 1/1 [00:00<00:00,  2.92it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.49it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.95it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.64it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.96it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.29it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.28it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.83it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.86it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.78it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.08it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.40it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.50it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.39it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.21it/s]
# 100%|██████████| 1/1 [00:00<00:00,  2.47it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.44it/s]
#   processed 75 / 281
# 100%|██████████| 1/1 [00:00<00:00,  5.20it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.38it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.42it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.33it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.38it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.96it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.06it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.80it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.38it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.12it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.97it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.74it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.45it/s]
# 100%|██████████| 1/1 [00:56<00:00, 56.44s/it]
# 100%|██████████| 1/1 [00:00<00:00,  4.77it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.39it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.05it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.11it/s]
# 100%|██████████| 1/1 [00:17<00:00, 17.78s/it]
# 100%|██████████| 1/1 [00:00<00:00,  4.06it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.41it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.17it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.51it/s]
# 100%|██████████| 1/1 [00:29<00:00, 29.28s/it]
# 100%|██████████| 1/1 [00:00<00:00,  4.42it/s]
#   processed 100 / 281
# 100%|██████████| 1/1 [00:00<00:00,  3.91it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.11it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.18it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.03it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.95it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.95it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.20it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.90it/s]
# 100%|██████████| 1/1 [00:00<00:00,  2.30it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.56it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.27it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.20it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.39it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.00it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.82it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.44it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.25it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.30it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.43it/s]
# 100%|██████████| 1/1 [00:22<00:00, 22.39s/it]
# 100%|██████████| 1/1 [00:00<00:00,  2.30it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.20it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.55it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.81it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.06it/s]
#   processed 125 / 281
# 100%|██████████| 1/1 [00:00<00:00,  5.46it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.08it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.48it/s]
# 100%|██████████| 1/1 [00:26<00:00, 26.54s/it]
# 100%|██████████| 1/1 [00:46<00:00, 46.71s/it]
# 100%|██████████| 1/1 [00:00<00:00,  2.53it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.35it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.29it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.51it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.26it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.50it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.87it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.67it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.56it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.79it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.62it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.97it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.47it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.36it/s]
# 100%|██████████| 1/1 [00:41<00:00, 41.87s/it]
# 100%|██████████| 1/1 [00:00<00:00,  4.61it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.25it/s]
# 100%|██████████| 1/1 [00:20<00:00, 20.01s/it]
# 100%|██████████| 1/1 [00:00<00:00,  3.59it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.05it/s]
#   processed 150 / 281
# 100%|██████████| 1/1 [00:00<00:00,  3.63it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.77it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.15it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.75it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.47it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.92it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.97it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.94it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.30it/s]
# 100%|██████████| 1/1 [00:00<00:00,  2.69it/s]
# 100%|██████████| 1/1 [00:00<00:00,  2.42it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.27it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.55it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.29it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.30it/s]
# 100%|██████████| 1/1 [00:00<00:00,  2.99it/s]
# 100%|██████████| 1/1 [00:00<00:00,  2.30it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.00it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.82it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.61it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.61it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.38it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.82it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.40it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.83it/s]
#   processed 175 / 281
# 100%|██████████| 1/1 [00:51<00:00, 51.35s/it]
# 100%|██████████| 1/1 [00:00<00:00,  4.34it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.12it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.79it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.47it/s]
# 100%|██████████| 1/1 [00:00<00:00,  2.63it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.41it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.02it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.24it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.33it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.07it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.38it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.29it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.50it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.05it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.59it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.00it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.13it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.84it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.10it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.86it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.17it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.33it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.13it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.03it/s]
#   processed 200 / 281
# 100%|██████████| 1/1 [00:00<00:00,  4.25it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.26it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.31it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.78it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.99it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.67it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.61it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.72it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.89it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.84it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.17it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.93it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.66it/s]
# 100%|██████████| 1/1 [00:00<00:00,  2.90it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.04it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.13it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.96it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.27it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.59it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.55it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.94it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.78it/s]
# 100%|██████████| 1/1 [00:10<00:00, 10.23s/it]
# 100%|██████████| 1/1 [00:00<00:00,  3.97it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.01it/s]
#   processed 225 / 281
# 100%|██████████| 1/1 [00:00<00:00,  4.09it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.78it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.26it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.82it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.10it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.82it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.75it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.39it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.62it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.43it/s]
# 100%|██████████| 1/1 [00:00<00:00,  2.45it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.06it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.04it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.63it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.29it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.14it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.95it/s]
# 100%|██████████| 1/1 [00:21<00:00, 21.85s/it]
# 100%|██████████| 1/1 [00:00<00:00,  4.96it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.34it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.02it/s]
# 100%|██████████| 1/1 [00:14<00:00, 14.05s/it]
# 100%|██████████| 1/1 [00:00<00:00,  3.55it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.16it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.32it/s]
#   processed 250 / 281
# 100%|██████████| 1/1 [00:00<00:00,  4.49it/s]
# 100%|██████████| 1/1 [00:20<00:00, 20.82s/it]
# 100%|██████████| 1/1 [00:00<00:00,  4.17it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.12it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.83it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.99it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.29it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.27it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.04it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.82it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.57it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.12it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.07it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.08it/s]
# 100%|██████████| 1/1 [00:00<00:00,  2.39it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.08it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.20it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.71it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.72it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.78it/s]
# 100%|██████████| 1/1 [00:00<00:00,  2.93it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.71it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.86it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.29it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.13it/s]
#   processed 275 / 281
# 100%|██████████| 1/1 [00:00<00:00,  5.25it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.31it/s]
# 100%|██████████| 1/1 [00:00<00:00,  2.59it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.14it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.25it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.08it/s]
# Saved -> /Users/matteopaolini/Library/Mobile Documents/com~apple~CloudDocs/erasmus/Secondo semestre/INFO-H512/project/infoh512-project-1/data/fairness/recourse_RF.csv

# %%
recourse_xgb = build_recourse_dataset(
    exp_xgb, xgb_wrapper, df_encoded, df_raw, feature_names,
    le_dict=xgb["label_encoders"], n_cf=N_CF, seed=SEED_DICE,
    threshold=THRESHOLD,
    checkpoint_path=os.path.join(PATHS["FAIRNESS"], "recourse_XGB.csv"),
)

print(f"\nDone. RF: {len(recourse_rf)} employees | XGB: {len(recourse_xgb)} employees")
recourse_rf.head()
# Out:
# Employees flagged at-risk (proba >= 0.2): 227
# 100%|██████████| 1/1 [00:00<00:00, 12.44it/s]
# 100%|██████████| 1/1 [00:00<00:00, 12.72it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.27it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.33it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.36it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.65it/s]
# 100%|██████████| 1/1 [00:00<00:00, 12.85it/s]
# 100%|██████████| 1/1 [00:00<00:00, 12.30it/s]
# 100%|██████████| 1/1 [00:00<00:00, 10.74it/s]
# 100%|██████████| 1/1 [00:00<00:00, 10.57it/s]
# 100%|██████████| 1/1 [00:00<00:00, 11.71it/s]
# 100%|██████████| 1/1 [00:00<00:00, 11.51it/s]
# 100%|██████████| 1/1 [00:00<00:00, 12.25it/s]
# 100%|██████████| 1/1 [00:00<00:00, 12.65it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.31it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.66it/s]
# 100%|██████████| 1/1 [00:02<00:00,  2.48s/it]
# 100%|██████████| 1/1 [00:00<00:00, 12.13it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.41it/s]
# 100%|██████████| 1/1 [00:00<00:00, 12.22it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.68it/s]
# 100%|██████████| 1/1 [00:00<00:00, 12.55it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.88it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.29it/s]
# 100%|██████████| 1/1 [00:00<00:00, 10.51it/s]
#   processed 25 / 227
# 100%|██████████| 1/1 [00:00<00:00, 13.99it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.50it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.64it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.05it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.05it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.89it/s]
# 100%|██████████| 1/1 [00:00<00:00, 12.80it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.54it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.28it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.42it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.04it/s]
# 100%|██████████| 1/1 [00:00<00:00, 12.74it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.10it/s]
# 100%|██████████| 1/1 [00:00<00:00,  9.60it/s]
# 100%|██████████| 1/1 [00:00<00:00,  6.16it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.79it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.88it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.33it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.89it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.32it/s]
# 100%|██████████| 1/1 [00:00<00:00, 15.10it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.66it/s]
# 100%|██████████| 1/1 [00:00<00:00, 15.01it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.62it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.26it/s]
#   processed 50 / 227
# 100%|██████████| 1/1 [00:00<00:00, 15.09it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.45it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.79it/s]
# 100%|██████████| 1/1 [00:00<00:00, 15.09it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.54it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.87it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.75it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.89it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.14it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.05it/s]
# 100%|██████████| 1/1 [00:00<00:00, 15.04it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.56it/s]
# 100%|██████████| 1/1 [00:00<00:00,  7.74it/s]
# 100%|██████████| 1/1 [00:00<00:00, 15.16it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.51it/s]
# 100%|██████████| 1/1 [00:00<00:00, 15.64it/s]
# 100%|██████████| 1/1 [00:00<00:00, 15.22it/s]
# 100%|██████████| 1/1 [00:00<00:00,  2.39it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.53it/s]
# 100%|██████████| 1/1 [00:00<00:00, 12.39it/s]
# 100%|██████████| 1/1 [00:00<00:00,  9.08it/s]
# 100%|██████████| 1/1 [00:00<00:00,  9.45it/s]
# 100%|██████████| 1/1 [00:02<00:00,  2.47s/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.33s/it]
# 100%|██████████| 1/1 [00:00<00:00, 13.92it/s]
#   processed 75 / 227
# 100%|██████████| 1/1 [00:00<00:00, 13.98it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.07it/s]
# 100%|██████████| 1/1 [00:00<00:00, 12.91it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.90it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.38it/s]
# 100%|██████████| 1/1 [00:00<00:00, 12.80it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.11it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.22it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.65it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.95it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.89it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.06it/s]
# 100%|██████████| 1/1 [00:00<00:00, 12.38it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.68it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.32it/s]
# 100%|██████████| 1/1 [00:00<00:00, 12.80it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.16it/s]
# 100%|██████████| 1/1 [00:00<00:00,  2.06it/s]
# 100%|██████████| 1/1 [00:00<00:00, 15.11it/s]
# 100%|██████████| 1/1 [00:00<00:00, 15.20it/s]
# 100%|██████████| 1/1 [00:00<00:00, 15.75it/s]
# 100%|██████████| 1/1 [00:00<00:00, 15.66it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.04it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.65it/s]
# 100%|██████████| 1/1 [00:00<00:00, 12.87it/s]
#   processed 100 / 227
# 100%|██████████| 1/1 [00:00<00:00, 13.09it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.62it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.87it/s]
# 100%|██████████| 1/1 [00:00<00:00, 10.75it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.83it/s]
# 100%|██████████| 1/1 [00:00<00:00,  9.49it/s]
# 100%|██████████| 1/1 [00:00<00:00, 10.89it/s]
# 100%|██████████| 1/1 [00:00<00:00, 11.16it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.79it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.09it/s]
# 100%|██████████| 1/1 [00:00<00:00, 11.47it/s]
# 100%|██████████| 1/1 [00:00<00:00, 12.10it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.17it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.10it/s]
# 100%|██████████| 1/1 [00:00<00:00, 12.15it/s]
# 100%|██████████| 1/1 [00:00<00:00, 12.89it/s]
# 100%|██████████| 1/1 [00:00<00:00, 11.87it/s]
# 100%|██████████| 1/1 [00:01<00:00,  1.01s/it]
# 100%|██████████| 1/1 [00:00<00:00,  5.21it/s]
# 100%|██████████| 1/1 [00:00<00:00, 12.45it/s]
# 100%|██████████| 1/1 [00:00<00:00, 12.30it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.74it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.17it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.05it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.07it/s]
#   processed 125 / 227
# 100%|██████████| 1/1 [00:00<00:00, 14.40it/s]
# 100%|██████████| 1/1 [00:00<00:00, 12.07it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.30it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.24it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.15it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.04it/s]
# 100%|██████████| 1/1 [00:01<00:00,  1.49s/it]
# 100%|██████████| 1/1 [00:00<00:00, 10.69it/s]
# 100%|██████████| 1/1 [00:00<00:00, 10.52it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.15it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.19it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.31it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.12it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.85it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.65it/s]
# 100%|██████████| 1/1 [00:01<00:00,  1.05s/it]
# 100%|██████████| 1/1 [00:00<00:00, 13.97it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.47it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.97it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.15it/s]
# 100%|██████████| 1/1 [00:00<00:00, 12.93it/s]
# 100%|██████████| 1/1 [00:00<00:00, 11.19it/s]
# 100%|██████████| 1/1 [00:00<00:00, 11.96it/s]
# 100%|██████████| 1/1 [00:00<00:00, 12.96it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.46it/s]
#   processed 150 / 227
# 100%|██████████| 1/1 [00:00<00:00, 12.52it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.08it/s]
# 100%|██████████| 1/1 [00:00<00:00, 11.67it/s]
# 100%|██████████| 1/1 [00:00<00:00, 10.69it/s]
# 100%|██████████| 1/1 [00:00<00:00, 11.96it/s]
# 100%|██████████| 1/1 [00:00<00:00, 11.89it/s]
# 100%|██████████| 1/1 [00:00<00:00,  6.61it/s]
# 100%|██████████| 1/1 [00:00<00:00,  5.87it/s]
# No Counterfactuals found for the given configuration, perhaps try with different parameters... ; total time taken: 00 min 00 sec
#   [warn] employee row 1016: DiCE failed (No counterfactuals found for any of the query points! Kindly check your configuration.)
# 100%|██████████| 1/1 [00:01<00:00,  1.88s/it]
# 100%|██████████| 1/1 [00:00<00:00, 14.82it/s]
# 100%|██████████| 1/1 [00:00<00:00, 12.71it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.97it/s]
# 100%|██████████| 1/1 [00:00<00:00, 12.46it/s]
# 100%|██████████| 1/1 [00:01<00:00,  1.66s/it]
# 100%|██████████| 1/1 [00:00<00:00, 14.87it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.19it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.00it/s]
# 100%|██████████| 1/1 [00:00<00:00, 11.53it/s]
# 100%|██████████| 1/1 [00:00<00:00, 12.51it/s]
# 100%|██████████| 1/1 [00:00<00:00, 12.87it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.45it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.17it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.29it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.61it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.67it/s]
#   processed 175 / 227
# 100%|██████████| 1/1 [00:00<00:00, 14.61it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.07it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.25it/s]
# 100%|██████████| 1/1 [00:00<00:00, 11.87it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.82it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.36it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.09it/s]
# 100%|██████████| 1/1 [00:00<00:00, 15.10it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.79it/s]
# 100%|██████████| 1/1 [00:01<00:00,  1.39s/it]
# 100%|██████████| 1/1 [00:00<00:00, 13.16it/s]
# 100%|██████████| 1/1 [00:00<00:00,  9.48it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.96it/s]
# 100%|██████████| 1/1 [00:01<00:00,  1.35s/it]
# 100%|██████████| 1/1 [00:00<00:00, 12.82it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.49it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.33it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.33it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.45it/s]
# 100%|██████████| 1/1 [00:00<00:00, 11.82it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.52it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.83it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.94it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.60it/s]
# 100%|██████████| 1/1 [00:00<00:00, 15.11it/s]
#   processed 200 / 227
# 100%|██████████| 1/1 [00:00<00:00, 13.59it/s]
# 100%|██████████| 1/1 [00:00<00:00, 15.21it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.69it/s]
# 100%|██████████| 1/1 [00:00<00:00, 15.01it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.45it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.57it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.62it/s]
# 100%|██████████| 1/1 [00:00<00:00, 11.57it/s]
# 100%|██████████| 1/1 [00:00<00:00, 12.16it/s]
# 100%|██████████| 1/1 [00:00<00:00, 12.80it/s]
# 100%|██████████| 1/1 [00:00<00:00,  6.24it/s]
# No Counterfactuals found for the given configuration, perhaps try with different parameters... ; total time taken: 00 min 00 sec
#   [warn] employee row 1338: DiCE failed (No counterfactuals found for any of the query points! Kindly check your configuration.)
# 100%|██████████| 1/1 [00:00<00:00, 12.82it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.51it/s]
# 100%|██████████| 1/1 [00:00<00:00, 12.55it/s]
# 100%|██████████| 1/1 [00:00<00:00,  7.25it/s]
# 100%|██████████| 1/1 [00:00<00:00, 11.97it/s]
# 100%|██████████| 1/1 [00:00<00:00, 12.55it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.98it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.77it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.00it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.72it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.55it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.54it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.32it/s]
# 100%|██████████| 1/1 [00:00<00:00, 10.97it/s]
#   processed 225 / 227
# 100%|██████████| 1/1 [00:00<00:00, 14.04it/s]
# 100%|██████████| 1/1 [00:00<00:00, 11.55it/s]
# Saved -> /Users/matteopaolini/Library/Mobile Documents/com~apple~CloudDocs/erasmus/Secondo semestre/INFO-H512/project/infoh512-project-1/data/fairness/recourse_XGB.csv
#
# Done. RF: 281 employees | XGB: 227 employees
#    emp_id  Gender AgeGroup  Age MaritalStatus              Department  \
# 0       0  Female   Senior   41        Single                   Sales
# 1       2    Male   Senior   37        Single  Research & Development
# 2       3  Female    Young   33       Married  Research & Development
# 3      14    Male    Young   28        Single  Research & Development
# 4      17    Male    Young   22      Divorced  Research & Development
#
#    true_attrition  predicted_risk  n_cf_found  recourse_found  L1_cost  \
# 0               1            76.0           3            True   1.1153
# 1               1            43.0           3            True   0.8125
# 2               0            27.5           3            True   0.5994
# 3               1            87.5           3            True   0.9092
# 4               0            36.5           3            True   0.3722
#
#                                        changed_feats
# 0  JobRole;StockOptionLevel;TrainingTimesLastYear...
# 1              BusinessTravel;JobInvolvement;JobRole
# 2  DistanceFromHome;JobLevel;JobRole;Relationship...
# 3  BusinessTravel;JobLevel;MonthlyIncome;OverTime...
# 4              TrainingTimesLastYear;WorkLifeBalance

# %% [markdown]
# ## 4. Level 1 — Prediction Fairness
#
# Three group-fairness notions (from the lecture slides):
# - **Statistical parity:** same predicted-positive rate per group
# - **Equal opportunity:** same recall (TPR) per group
# - **Predictive equality:** same FPR per group

# %%
def prediction_fairness(wrapper, df_encoded, df_raw, feature_names,
                        protected_attr, threshold=THRESHOLD):
    X      = df_encoded[feature_names].astype("float64")
    proba  = wrapper.predict_proba(X)[:, 1]
    y_pred = (proba >= threshold).astype(int)
    y_true = df_raw["Attrition"].values
    rows   = []
    for g in sorted(df_raw[protected_attr].dropna().unique()):
        mask = (df_raw[protected_attr] == g).values
        yt, yp = y_true[mask], y_pred[mask]
        pos, neg = yt == 1, yt == 0
        rows.append({
            protected_attr:        g,
            "n":                   int(mask.sum()),
            "pred_positive_rate":  round(yp.mean(), 3),
            "TPR_recall":          round(yp[pos].mean(), 3) if pos.any() else float("nan"),
            "FPR":                 round(yp[neg].mean(), 3) if neg.any() else float("nan"),
        })
    return pd.DataFrame(rows)

# %%
for model_name, wrapper in [("Random Forest", rf_wrapper), ("XGBoost", xgb_wrapper)]:
    print(f"\n{'='*60}\n{model_name} — Prediction Fairness\n{'='*60}")
    for attr in PROTECTED_ATTRIBUTES:
        tbl = prediction_fairness(wrapper, df_encoded, df_raw, feature_names, attr)
        gaps = {m: round(tbl[m].max() - tbl[m].min(), 3)
                for m in ["pred_positive_rate", "TPR_recall", "FPR"]}
        print(f"\n-- {attr} --")
        print(tbl.to_string(index=False))
        print(f"   gaps (max-min): {gaps}")
# Out:
# ============================================================
# Random Forest — Prediction Fairness
# ============================================================
#
# -- Gender --
# Gender   n  pred_positive_rate  TPR_recall   FPR
# Female 588               0.185       0.897 0.062
#   Male 882               0.195       0.873 0.056
#    gaps (max-min): {'pred_positive_rate': 0.01, 'TPR_recall': 0.024, 'FPR': 0.006}
#
# -- AgeGroup --
# AgeGroup   n  pred_positive_rate  TPR_recall   FPR
#   Senior 819               0.109       0.793 0.027
#    Young 651               0.295       0.933 0.104
#    gaps (max-min): {'pred_positive_rate': 0.186, 'TPR_recall': 0.14, 'FPR': 0.077}
#
# -- MaritalStatus --
# MaritalStatus   n  pred_positive_rate  TPR_recall   FPR
#      Divorced 327               0.131       0.909 0.044
#       Married 673               0.138       0.821 0.041
#        Single 470               0.309       0.917 0.100
#    gaps (max-min): {'pred_positive_rate': 0.178, 'TPR_recall': 0.096, 'FPR': 0.059}
#
# ============================================================
# XGBoost — Prediction Fairness
# ============================================================
#
# -- Gender --
# Gender   n  pred_positive_rate  TPR_recall   FPR
# Female 588               0.150       0.851 0.028
#   Male 882               0.158       0.800 0.026
#    gaps (max-min): {'pred_positive_rate': 0.008, 'TPR_recall': 0.051, 'FPR': 0.002}
#
# -- AgeGroup --
# AgeGroup   n  pred_positive_rate  TPR_recall   FPR
#   Senior 819               0.087       0.701 0.014
#    Young 651               0.240       0.887 0.046
#    gaps (max-min): {'pred_positive_rate': 0.153, 'TPR_recall': 0.186, 'FPR': 0.032}
#
# -- MaritalStatus --
# MaritalStatus   n  pred_positive_rate  TPR_recall   FPR
#      Divorced 327               0.107       0.879 0.020
#       Married 673               0.111       0.762 0.019
#        Single 470               0.249       0.842 0.046
#    gaps (max-min): {'pred_positive_rate': 0.142, 'TPR_recall': 0.117, 'FPR': 0.027}

# %% [markdown]
# ## 5. Visualise predicted attrition rate by group

# %%
fig, axes = plt.subplots(1, len(PROTECTED_ATTRIBUTES),
                         figsize=(5 * len(PROTECTED_ATTRIBUTES), 4))
for ax, attr in zip(axes, PROTECTED_ATTRIBUTES):
    rf_tbl  = prediction_fairness(rf_wrapper,  df_encoded, df_raw, feature_names, attr)
    xgb_tbl = prediction_fairness(xgb_wrapper, df_encoded, df_raw, feature_names, attr)
    x = np.arange(len(rf_tbl))
    ax.bar(x - 0.2, rf_tbl["pred_positive_rate"],  0.4, label="RF",  color="#2196F3")
    ax.bar(x + 0.2, xgb_tbl["pred_positive_rate"], 0.4, label="XGB", color="#FF9800")
    ax.set_xticks(x)
    ax.set_xticklabels(rf_tbl[attr], rotation=20, ha="right")
    ax.set_title(f"Predicted attrition rate — {attr}")
    ax.set_ylabel("rate")
    ax.legend()
plt.tight_layout()
plt.savefig(os.path.join(PATHS["FAIRNESS"], "level1_prediction_fairness.png"), dpi=120)
plt.show()
print("Level 1 done. Proceed to 05_counterfactual_fairness.ipynb")
# Out:
# Level 1 done. Proceed to 05_counterfactual_fairness.ipynb

# %%
# ─────────────────────────────────────────────────────────────────────────────
# DIAGNOSTICA — validazione risultati notebook 04
# ─────────────────────────────────────────────────────────────────────────────
SEP = "=" * 65

# ── 1. DATASET ────────────────────────────────────────────────────────────────
print(SEP)
print("1. DATASET")
print(SEP)
print(f"  Totale dipendenti  : {len(df_raw)}")
print(f"  Feature usate      : {len(feature_names)}")
print(f"  Attrition reale    : {df_raw['Attrition'].sum()} / {len(df_raw)} ({df_raw['Attrition'].mean():.1%})")
print()
for attr in ['Gender', 'AgeGroup', 'MaritalStatus']:
    print(f"  {attr}:")
    print(df_raw[attr].value_counts().to_string())
    print()

# ── 2. MODELLI ────────────────────────────────────────────────────────────────
print(SEP)
print("2. SANITY CHECK MODELLI (threshold=0.20)")
print(SEP)
X_all  = df_encoded[feature_names].astype('float64')
y_true = df_raw['Attrition'].values

for name, wrapper in [('Random Forest', rf_wrapper), ('XGBoost', xgb_wrapper)]:
    proba = wrapper.predict_proba(X_all)[:, 1]
    pred  = (proba >= THRESHOLD).astype(int)
    tp = ((pred==1) & (y_true==1)).sum()
    fp = ((pred==1) & (y_true==0)).sum()
    fn = ((pred==0) & (y_true==1)).sum()
    print(f"  {name}:")
    print(f"    At-risk predetti : {pred.sum()} ({pred.mean():.1%})")
    print(f"    Recall           : {tp/(tp+fn):.1%}  |  Precision: {tp/(tp+fp):.1%}")
    print(f"    Proba media      : {proba.mean():.3f}  |  max: {proba.max():.3f}")
    print()

# ── 3. RECOURSE DATASET ───────────────────────────────────────────────────────
print(SEP)
print("3. RECOURSE DATASET")
print(SEP)
for name, rdf in [('Random Forest', recourse_rf), ('XGBoost', recourse_xgb)]:
    found = rdf['recourse_found'].sum()
    total = len(rdf)
    costs = rdf.loc[rdf['recourse_found'], 'L1_cost']
    print(f"  {name}:")
    print(f"    At-risk processati : {total}")
    print(f"    Recourse trovato   : {found} ({found/total:.1%})")
    print(f"    Costo L1 medio     : {costs.mean():.4f}  |  mediano: {costs.median():.4f}")
    print()

# ── 4. FACTS PREVIEW ─────────────────────────────────────────────────────────
print(SEP)
print("4. FACTS PREVIEW — gap di fairness sul recourse")
print(SEP)
for name, rdf in [('Random Forest', recourse_rf), ('XGBoost', recourse_xgb)]:
    print(f"  {name}:")
    for attr in ['Gender', 'AgeGroup', 'MaritalStatus']:
        rows = []
        for g in sorted(rdf[attr].dropna().unique()):
            sub  = rdf[rdf[attr] == g]
            eff  = sub['recourse_found'].mean()
            cost = sub.loc[sub['recourse_found'], 'L1_cost'].median()
            rows.append((g, len(sub), eff, cost))
        print(f"    {attr}:")
        for g, n, eff, cost in rows:
            print(f"      {str(g):15s} n={n:4d}  eff={eff:.1%}  median_cost={cost:.4f}")
        gap = round(max(r[2] for r in rows) - min(r[2] for r in rows), 3)
        print(f"      → GAP: {gap}  {'⚠️  unfair' if gap > 0.05 else '✅ ok'}")
    print()

# ── 5. FILE SALVATI ───────────────────────────────────────────────────────────
print(SEP)
print("5. FILE SALVATI")
print(SEP)
for fname in sorted(os.listdir(PATHS['FAIRNESS'])):
    fpath = os.path.join(PATHS['FAIRNESS'], fname)
    print(f"  ✅ {fname}  ({os.path.getsize(fpath):,} bytes)")
# Out:
# =================================================================
# 1. DATASET
# =================================================================
#   Totale dipendenti  : 1470
#   Feature usate      : 30
#   Attrition reale    : 237 / 1470 (16.1%)
#
#   Gender:
# Gender
# Male      882
# Female    588
#
#   AgeGroup:
# AgeGroup
# Senior    819
# Young     651
#
#   MaritalStatus:
# MaritalStatus
# Married     673
# Single      470
# Divorced    327
#
# =================================================================
# 2. SANITY CHECK MODELLI (threshold=0.20)
# =================================================================
#   Random Forest:
#     At-risk predetti : 281 (19.1%)
#     Recall           : 88.2%  |  Precision: 74.4%
#     Proba media      : 0.156  |  max: 0.940
#
#   XGBoost:
#     At-risk predetti : 227 (15.4%)
#     Recall           : 81.9%  |  Precision: 85.5%
#     Proba media      : 0.148  |  max: 1.000
#
# =================================================================
# 3. RECOURSE DATASET
# =================================================================
#   Random Forest:
#     At-risk processati : 281
#     Recourse trovato   : 281 (100.0%)
#     Costo L1 medio     : 0.8437  |  mediano: 0.7824
#
#   XGBoost:
#     At-risk processati : 227
#     Recourse trovato   : 225 (99.1%)
#     Costo L1 medio     : 0.8266  |  mediano: 0.7528
#
# =================================================================
# 4. FACTS PREVIEW — gap di fairness sul recourse
# =================================================================
#   Random Forest:
#     Gender:
#       Female          n= 109  eff=100.0%  median_cost=0.7597
#       Male            n= 172  eff=100.0%  median_cost=0.8118
#       → GAP: 0.0  ✅ ok
#     AgeGroup:
#       Senior          n=  89  eff=100.0%  median_cost=0.7929
#       Young           n= 192  eff=100.0%  median_cost=0.7757
#       → GAP: 0.0  ✅ ok
#     MaritalStatus:
#       Divorced        n=  43  eff=100.0%  median_cost=0.7278
#       Married         n=  93  eff=100.0%  median_cost=0.7113
#       Single          n= 145  eff=100.0%  median_cost=0.8361
#       → GAP: 0.0  ✅ ok
#
#   XGBoost:
#     Gender:
#       Female          n=  88  eff=98.9%  median_cost=0.7153
#       Male            n= 139  eff=99.3%  median_cost=0.7583
#       → GAP: 0.004  ✅ ok
#     AgeGroup:
#       Senior          n=  71  eff=100.0%  median_cost=0.7389
#       Young           n= 156  eff=98.7%  median_cost=0.7604
#       → GAP: 0.013  ✅ ok
#     MaritalStatus:
#       Divorced        n=  35  eff=100.0%  median_cost=0.6368
#       Married         n=  75  eff=100.0%  median_cost=0.7317
#       Single          n= 117  eff=98.3%  median_cost=0.7962
#       → GAP: 0.017  ✅ ok
#
# =================================================================
# 5. FILE SALVATI
# =================================================================
#   ✅ level1_prediction_fairness.png  (51,833 bytes)
#   ✅ level2_cf_fairness_atrisk.csv  (101 bytes)
#   ✅ level2_cf_fairness_full.csv  (83 bytes)
#   ✅ level2_counterfactual_fairness.png  (37,370 bytes)
#   ✅ recourse_RF.csv  (35,555 bytes)
#   ✅ recourse_XGB.csv  (26,173 bytes)
#   ✅ sensitivity_tight_RF.csv  (12,615 bytes)
